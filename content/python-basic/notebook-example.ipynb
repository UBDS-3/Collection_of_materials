# %% [markdown]
# # Jupyter notebook example
#
# Quarto publishes notebooks as first-class pages in the same website.

# %%
values = [2, 4, 6, 8]
print(f"Mean: {sum(values) / len(values)}")
# Out:
# Mean: 5.0
